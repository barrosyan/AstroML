# %% [markdown]
# <a href="https://colab.research.google.com/github/barrosyan/AstroML/blob/main/Star_Evollution_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stellar Evolution Model With Neural Networks - Yan Barros
#
# #### Reference: http://spiff.rit.edu/classes/phys370/lectures/statstar/statstar.html

# %% [markdown]
# #### The repository was used as the main base for generating data, however, i had to choose initial conditions for stars, based on Milky Way patterns. This is stored in a csv file which I used to feed the package tool and run a loop to generate my data for the project.

# %% [markdown]
# # Step 1 - Importing packages

# %%
import os
import csv
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf

# %% [markdown]
# # Step 2 - Adaptating the main functions of the StatStar package

# %%
#  This program is a adaptation of a Python version of the code STATSTAR written
#  in FORTRAN and described in Carroll and Ostlie.  Program
#  has been modified and converted to Python in Fall 2010
#  by Prof. D. Schiminovich at Columbia University
#  for use in C3101 Stellar Structure and Evolution
#
#  Notes from FORTRAN code:
#
#  This program is listed in Appendix H of both "An Introduction
#  to Modern Astrophysics," Bradley W. Carroll and Dale A. Ostlie,
#  Addison-Wesley Publishing Company, copyright 1996, and "An
#  Introduction to Modern Stellar Astrophysics," Dale A. Ostlie
#  and Bradley W. Carroll, Addison-Wesley Publishing Company,
#  copyright 1996.
#
#  This program will calculate a static stellar model using the
#  equations developed in the text.  The user is expected to supply the
#  star's mass, luminosity, effective temperature, and composition
#  (X and Z).  If the choices for these quantities are not consistent
#  with the central boundary conditions, an error message will be
#  generated and the user will then need to supply a different set of
#  initial values.

#  SUBROUTINES

#  Subroutine STARTMDL computes values of M_r, L_r, P, and T, near the
#  surface of the star using expansions of the stellar structure
#  equations (M_r and L_r are assumed to be constant).
#
def STARTMDL(deltar, X, Z, mu, Rs, r_i, M_ri, L_ri, tog_bf,irc,cst):
#
#     X = hydrogen mass fraction
#     Z = metal mass fraction
#     mu = mean molecular weight
#     Rs = radius of star
#     r_i = radius of shell
#     M_ri = mass enclosed within shell at this radius
#          (assumed constant at start of model)
#     L_ri = enclosed luminosity, assumed constant
#
      r = r_i + deltar
      M_rip1 = M_ri
      L_rip1 = L_ri
#
#  This is the radiative approximation (neglect radiation pressure
#  and electron scattering opacity)# see Prialnik Eq. 5.1, 5.3 and Sec. 3.7 or C&O Eqs. (H.1), (H.2), (9.19),
#  and (9.20).
#
      if (irc == 0):
          T_ip1 = cst.G*M_rip1*mu*cst.m_H/(4.25e0*cst.k_B)*(1.0e0/r - 1.0e0/Rs)
          A_bf = 4.34e25*Z*(1.0e0 + X)/tog_bf
          A_ff = 3.68e22*cst.g_ff*(1.0e0 - Z)*(1.0e0 + X)
          Afac = A_bf + A_ff
          P_ip1 = np.sqrt((1.0e0/4.25e0)*(16.0e0/3.0e0*np.pi*cst.a*cst.c)*(cst.G*M_rip1/L_rip1)*(cst.k_B/(Afac*mu*cst.m_H)))*T_ip1**4.25e0

#
#  This is the convective approximation# see Prialnik Sec 6.5, 6.6 or C&O Eqs. (H.3) and (10.75).
#
      else:
          T_ip1 = cst.G*M_rip1*mu*cst.m_H/cst.k_B*(1.0e0/r - 1.0e0/Rs)/cst.gamrat
          P_ip1 = cst.kPad*T_ip1**cst.gamrat

      return r,P_ip1, M_rip1, L_rip1, T_ip1

#
#  Subroutine EOS calculates the values of density, opacity, the
#  guillotine-to-gaunt factor ratio, and the energy generation rate at
#  the radius r.
#
def   EOS(X, Z, XCNO, mu, P, T,izone,cst):

#
#  Solve for density from the ideal gas law (remove radiation pressure)#
#  see Prialnik Eq. 5.5 or C&O Eq. (10.26).
#
      if ((T < 0.0e0) or (P < 0.0e0)):
          print(' Something is a little wrong here.')
          print(' You are asking me to deal with either a negative temperature')
          print(' or a negative pressure.  I am sorry but that is not in my')
          print(' contract! You will have to try again with different')
          print(' initial conditions.')
          print(' In case it helps, I detected the problem in zone ',izone)
          print(' with the following conditions:')
          print('T = ',T,' K')
          print('P = ',P,' dynes/cm**2')
          return (0.0, 0.0, 0.0,0.0,1)


      Prad = cst.a*T**4/3.0e0
      Pgas = P - Prad
      rho=(mu*cst.m_H/cst.k_B)*(Pgas/T)
      if (rho < 0.0e0):
          print(' I am sorry, but a negative density was detected.')
          print(' my equation-of-state routine is a bit baffled by this new')
          print(' physical system you have created.  The radiation pressure')
          print(' is probably too great, implying that the star is unstable.')
          print(' Please try something a little less radical next time.')
          print(' In case it helps, I detected the problem in zone ')
          print(' with the following conditions:')
          print('T       = {0:12.5E} K'.format(T))
          print('P_total = {0:12.5E} dynes/cm**2'.format(P))
          print('P_rad   = {0:12.5E} dynes/cm**2'.format(Prad))
          print('P_gas   = {0:12.5E} dynes/cm**2'.format(Pgas))
          print('rho     = {0:12.5E} g/cm**3'.format(rho))
          return (rho, 0.0 , 0.0 ,0.0,1)

#
#  Calculate opacity, including the guillotine-to-gaunt factor ratio#
#  see Novotny (1973), p. 469. k_bf, k_ff, and k_e are the bound-free,
#  free-free, and electron scattering opacities, given by Prialnik Sec 3.7 or C&O Eqs. (9.19),
#  (9.20), and (9.21), respectively.
#

      tog_bf = 2.82e0*(rho*(1.0e0 + X))**0.2e0
      k_bf = 4.34e25/tog_bf*Z*(1.0e0 + X)*rho/T**3.5e0
      k_ff = 3.68e22*cst.g_ff*(1.0e0 - Z)*(1.0e0 + X)*rho/T**3.5e0
      k_e = 0.2e0*(1.0e0 + X)
      kappa = k_bf + k_ff + k_e
#
#  Compute energy generation by the pp chain and the CNO cycle.  These
#  are calculated using Eqs. (10.49) and (10.53) Prialnik Eq. 4.6, 4.7 + screening factor, which come from
#  Fowler, Caughlan, and Zimmerman (1975). The screening factor for the
#  pp chain is calculated as fpp# see Clayton (1968), p. 359ff.
#
#     Calculate 1/3 and 2/3 for convenience
      oneo3=0.333333333e0
      twoo3=0.666666667e0

      T6 = T*1.0e-06
      fx = 0.133e0*X*np.sqrt((3.0e0 + X)*rho)/T6**1.5e0
      fpp = 1.0e0 + fx*X
      psipp = 1.0e0 + 1.412e8*(1.0e0/X - 1.0e0)*np.exp(-49.98*T6**((-1.0)*oneo3))
      Cpp = 1.0e0 + 0.0123e0*T6**oneo3 + 0.0109e0*T6**twoo3 + 0.000938e0*T6
      epspp = 2.38e6*rho*X*X*fpp*psipp*Cpp*T6**(-twoo3)*np.exp(-33.80e0*T6**(-oneo3))
      CCNO = 1.0e0 + 0.0027e0*T6**oneo3 - 0.00778e0*T6**twoo3- 0.000149e0*T6
      epsCNO = 8.67e27*rho*X*XCNO*CCNO*T6**(-twoo3)*np.exp(-152.28e0*T6**(-oneo3))
      epslon = epspp + epsCNO

      return (rho, kappa, epslon,tog_bf,0)


#
#  The following four function subprograms calculate the gradients of
#  pressure, mass, luminosity, and temperature at r.

def dPdr(r, M_r, rho,cst):
      return -cst.G*rho*M_r/r**2

def dMdr(r, rho, cst):
      return (4.0e0*np.pi*rho*r**2)

def dLdr(r, rho, epslon,cst):
      return (4.0e0*np.pi*rho*epslon*r**2)

def dTdr(r, M_r, L_r, T, rho, kappa, mu, irc,cst):
      if (irc == 0):
          return (-(3.0e0/(16.0e0*np.pi*cst.a*cst.c))*kappa*rho/T**3*L_r/r**2)
#  This is the adiabatic convective temperature gradient (Prialnik Eq. 6.29 or C&O Eq. 10.81).
      else:
          return (-1.0e0/cst.gamrat*cst.G*M_r/r**2*mu*cst.m_H/cst.k_B)

#
# Runge-kutta algorithm
#
def RUNGE(f_im1, dfdr, r_im1, deltar, irc, X, Z, XCNO,mu, izone,cst):

      f_temp=np.zeros(4)
      f_i=np.zeros(4)

      dr12 = deltar/2.0e0
      dr16 = deltar/6.0e0
      r12  = r_im1 + dr12
      r_i  = r_im1 + deltar
#
#  Calculate intermediate derivatives from the four fundamental stellar
#  structure equations found in Subroutine FUNDEQ.
#
      for i in range(0,4):
          f_temp[i] = f_im1[i] + dr12*dfdr[i]

      df1, ierr = FUNDEQ(r12, f_temp, irc, X, Z, XCNO, mu, izone,cst)
      if (ierr != 0):
          return f_i,ierr
#

      for i in range(0,4):
          f_temp[i] = f_im1[i] + dr12*df1[i]

      df2,ierr = FUNDEQ(r12, f_temp, irc, X, Z, XCNO, mu, izone,cst)
      if (ierr != 0):
          return f_i,ierr

#
      for i in range(0,4):
          f_temp[i] = f_im1[i] + deltar*df2[i]

      df3,ierr=FUNDEQ(r_i, f_temp, irc, X, Z, XCNO, mu, izone,cst)
      if (ierr != 0):
          return f_i,ierr
#
#  Calculate the variables at the next shell (i + 1).
#
      for i in range(0,4):
          f_i[i] = f_im1[i] + dr16*(dfdr[i] + 2.0e0*df1[i] + 2.0e0*df2[i] + df3[i])

      return f_i,0


#
#  This subroutine returns the required derivatives for RUNGE, the
#  Runge-Kutta integration routine.
#
#      Subroutine FUNDEQ(r, f, irc, X, Z, XCNO, mu, izone,cst)

def FUNDEQ(r,f,irc,X,Z,XCNO,mu,izone,cst):

      dfdr=np.zeros(4)
      P   = f[0]
      M_r = f[1]
      L_r = f[2]
      T   = f[3]
      rho,kappa,epslon,tog_bf,ierr = EOS(X, Z, XCNO, mu, P, T, izone,cst)
      dfdr[0] = dPdr(r, M_r, rho,cst)
      dfdr[1] = dMdr(r, rho,cst)
      dfdr[2] = dLdr(r, rho, epslon,cst)
      dfdr[3] = dTdr(r, M_r, L_r, T, rho, kappa, mu, irc,cst)
      return (dfdr,ierr)



def StatStar(Msolar,Lsolar,Te,X,Z,iname):

#
#  Main program for calculating stellar structure
#
#  Variables, run-time parameters and settings:
#
#  deltar = radius integration step
#  idrflg = set size flag
#         = 0 (initial surface step size of Rs/1000.)
#         = 1 (standard step size of Rs/100.)
#         = 2 (core step size of Rs/5000.)
#
#  Nstart = number of steps for which starting equations are to be used
#           (the outermost zone is assumed to be radiative)
#  Nstop = maximum number of allowed zones in the star
#  Igoof = final model condition flag
#        = -1 (number of zones exceeded; also the initial value)
#        =  0 (good model)
#        =  1 (core density was extreme)
#        =  2 (core luminosity was extreme)
#        =  3 (extrapolated core temperature is too low)
#        =  4 (mass became negative before center was reached)
#        =  5 (luminosity became negative before center was reached)
#  X, Y, Z = mass fractions of hydrogen, helium, and metals
#  T0, P0 = surface temperature and pressure (T0 = P0 = 0 is assumed)
#  Ms, Ls, Rs = mass, luminosity, and radius of the star (cgs units)
#

      nsh=999   # maximum number of shells

      # initialize r, P, M_r, L_r, T, rho, kappa, epslon, dlPdlT to
      # an array with nsh elements

      r=np.zeros(nsh,float)
      P=np.zeros(nsh,float)
      M_r=np.zeros(nsh,float)
      L_r=np.zeros(nsh,float)
      T=np.zeros(nsh,float)
      rho=np.zeros(nsh,float)
      kappa=np.zeros(nsh,float)
      epslon=np.zeros(nsh,float)
      tog_bf=np.zeros(nsh,float)
      dlPdlT=np.zeros(nsh,float)

      # initialize other variables

      deltar=0.0
      XCNO=0.0
      mu=0.0
      Ms=0.0
      Ls=0.0
      Rs=0.0
      T0=0.0
      P0=0.0
      Pcore=0.0
      Tcore=0.0
      rhocor=0.0
      epscor=0.0
      rhomax=0.0
      Rsolar=0.0

      Y=1.0-(X+Z)


      #     tog_bf = bound-free opacity constant
      #             (ratio of guillotine to gaunt factors)
      tog_bf0=0.01


      # initialize variables used for 4 structure equation derivatives

      f_im1=np.zeros(4,float)
      dfdr=np.zeros(4,float)
      f_i=np.zeros(4,float)


      # Various run time parameters

      Nstart=10
      Nstop=999
      Igoof=-1
      ierr=0
      P0=0.0
      T0=0.0
      dlPlim=99.9
      debug=0

      #
      #  Assign values to constants (cgs units)
      #     Rsun = radius of the Sun
      #     Msun = mass of the Sun
      #     Lsun = luminosity of the Sun
      #     sigma = Stefan-Boltzmann constant
      #     c = speed of light in vacuum
      #     a = 4*sigma/c (radiation pressure constant)
      #     G = universal gravitational constant
      #     K_B = Boltzmann constant
      #     m_H = mass of hydrogen atom
      #     gamma = 5/3 (adiabatic gamma for a monatomic gas)
      #     gamrat = gamma/(gamma-1)
      #     kPad = P/T**(gamma/(gamma-1)) (adiabatic gas law constant)
      #     g_ff = free-free opacity gaunt factor (assumed to be unity)
      #

      Rsun=6.9599e10
      Msun=1.989e33
      Lsun=3.826e33

      # For convenience we will store most constants in a single variable

      class Constants:
           pass
      cst = Constants()

      cst.sigma=5.67051e-5
      cst.c=2.99792458e10
      cst.a=7.56591e-15
      cst.G=6.67259e-8
      cst.k_B=1.380658e-16
      cst.m_H=1.673534e-24
      cst.gamma= 5.0e0/3
      cst.g_ff= 1.0e0

#
#  Select the mass fraction CNO to be 50% of Z.
#
      XCNO = Z/2.0e0
#
#  Calculate the mass, luminosity, and radius of the star.
#  The radius is calculated from Prialnik Eq. 1.3 (C&O Eq. 3.17).
#
      Ms = Msolar*Msun
      Ls = Lsolar*Lsun
      Rs = np.sqrt(Ls/(4.e0*np.pi*cst.sigma))/Te**2
      Rsolar = Rs/Rsun
#
#  Begin with a very small step size since surface conditions vary
#  rapidly.
#
      deltar = -Rs/1000.0e0
      idrflg = 0
#
#  Calculate mean molecular weight mu assuming complete ionization
#  (see Prialnik Eq. 3.18, 3.25 or C&O Eq. 10.21).
#
      mu = 1.0e0/(2.0*X + 0.75*Y + 0.5*Z)
#
#  Calculate the delimiter between adiabatic convection and radiation
#  (see Prialnik Eq. 6.28 or C&O Eq. 10.87).
#
      cst.gamrat = cst.gamma/(cst.gamma - 1.0e0)
#
#  Initialize values of r, P, M_r, L_r, T, rho, kappa, and epslon at
#  the surface.  The outermost zone is assumed to be zone 1.  The zone
#  number increases toward the center.
#

      initsh=0
      r[initsh]   = Rs
      M_r[initsh] = Ms
      L_r[initsh] = Ls
      T[initsh]   = T0
      P[initsh]   = P0
      tog_bf[initsh]   = tog_bf0


      if (P0 <= 0.0) or (T0 <= 0.0):
          rho[initsh]    = 0.0
          kappa[initsh]  = 0.0
          epslon[initsh] = 0.0
          tog_bf[initsh] = 0.01
      else:
          rho[initsh],kappa[initsh],epslon[initsh],tog_bf[initsh],ierr=EOS(X, Z, XCNO, mu, P[initsh], T[initsh], 0 ,cst)
          if ierr != 0:
              print ("we're stopping now")
              istop=0

#
#  Apply approximate surface solutions to begin the integration,
#  assuming radiation transport in the outermost zone (the do 20 loop).
#  irc = 0 for radiation, irc = 1 for convection.
#  Assume arbitrary initial values for kPad, and dlPdlT.
#  dlPdlT = dlnP/dlnT (see Prialnik Eq. 6.28 or C&O Eq. 10.87)
#
      cst.kPad = 0.3e0
      irc = 0
      dlPdlT[initsh] = 4.25e0
      for i in range(0,Nstart):
          ip1 = i + 1
          r[ip1],P[ip1],M_r[ip1],L_r[ip1],T[ip1]=STARTMDL(deltar, X, Z, mu, Rs, r[i], M_r[i], L_r[i], tog_bf[i], irc,cst)
          rho[ip1],kappa[ip1],epslon[ip1],tog_bf[ip1],ierr=EOS(X, Z, XCNO, mu, P[ip1], T[ip1], ip1 ,cst)

          if ierr != 0:
              print('Values from the previous zone are:')
              print('r/Rs      = {0:12.5E}'.format(r[i]/Rs))
              print('rho       = {0:12.5E}  g/cm**3'.format(rho[i]))
              print('M_r/Ms    = {0:12.5E}'.format(M_r[i]/Ms))
              print('kappa     = {0:12.5E}  cm**2/g'.format(kappa[i]))
              print('T         = {0:12.5E}  K'.format(T[i]))
              print('epsilon   = {0:12.5E}  ergs/g/s'.format(epslon[i]))
              print('P         = {0:12.5E}  dynes/cm**2'.format(P[i]))
              print('L_r/Ls    = {0:12.5E}'.format(L_r[i]/Ls))
              break
#
#  Determine whether convection will be operating in the next zone by
#  calculating dlnP/dlnT numerically between zones i and i+1 [ip1].
#  Update the adiabatic gas constant if necessary.
#
          if (i > initsh):
              dlPdlT[ip1] = np.log(P[ip1]/P[i])/np.log(T[ip1]/T[i])
          else:
              dlPdlT[ip1] = dlPdlT[i]

          if (dlPdlT[ip1] < cst.gamrat):
              irc = 1
          else:
              irc = 0
              cst.kPad = P[ip1]/T[ip1]**cst.gamrat

#
#  Test to see whether the surface assumption of constant mass is still
#  valid.
#
          deltaM = deltar*dMdr(r[ip1], rho[ip1],cst)
          M_r[ip1] = M_r[i] + deltaM
          if (np.abs(deltaM) > (0.001e0*Ms)):
              if (ip1 > 1):
                  ip1 = ip1 - 1
                  print(' The variation in mass has become larger than 0.001*Ms')
                  print(' leaving the approximation loop before Nstart was reached')
                  break
#
#
#  =============  MAIN LOOP ==========================
#
#  This is the main integration loop.  The assumptions of constant
#  interior mass and luminosity are no longer applied.
#
#  Initialize the Runge-Kutta routine by specifying zone i-1 quantities
#  and their derivatives.  Note that the pressure, mass, luminosity,
#  and temperature are stored in the memory locations f_im1(1),
#  f_im1(2), f_im1(3), and f_im1(4), respectively.  The derivatives of
#  those quantities with respect to radius are stored in dfdr(1),
#  dfdr(2), dfdr(3), and dfdr(4).  Finally, the resulting values for
#  P, M_r, L_r, and T are returned from the Runge-Kutta routine in
#  f_i(1), f_i(2), f_i(3), and f_i(4), respectively.
#
#  The stellar structure equations
#           dPdr (Prialnik 5.1 or C&O Eq. 10.7)
#           dMdr (Prialnik 5.2 or C&O Eq. 10.8)
#           dLdr (Prialnik 5.4 or C&O Eq. 10.45) and
#           dTdr (Prialnik 5.3 or C&O Eq. 10.61 or Eq. 10.81)
#           are calculated in function calls, defined previously in the code.
#

      Nsrtp1 = ip1 + 1

      if (ierr != 0):    # exit if we've arrived at this point after an error in initialization
          Nstop=Nsrtp1-1
          istop=Nstop

      for i in range(Nsrtp1,Nstop):
          im1 = i - 1
          f_im1[0] = P[im1]
          f_im1[1] = M_r[im1]
          f_im1[2] = L_r[im1]
          f_im1[3] = T[im1]
          dfdr[0]  = dPdr(r[im1], M_r[im1], rho[im1],cst)
          dfdr[1]  = dMdr(r[im1], rho[im1],cst)
          dfdr[2]  = dLdr(r[im1], rho[im1], epslon[im1],cst)
          dfdr[3]  = dTdr(r[im1], M_r[im1], L_r[im1], T[im1], rho[im1],kappa[im1], mu, irc,cst)
          f_i,ierr=RUNGE(f_im1, dfdr, r[im1], deltar, irc, X, Z, XCNO, mu, i,cst)

          if (ierr != 0):
              print(' The problem occurred in the Runge-Kutta routine')
              print(' Values from the previous zone are:')
              print('r/Rs    = {0:12.5e}'.format(r[im1]/Rs))
              print('rho     = {0:12.5e} g/cm**3'.format(rho[im1]))
              print('M_r/Ms  = {0:12.5e}'.format(M_r[im1]/Ms))
              print('kappa   = {0:12.5e} cm**2/g'.format(kappa[im1]))
              print('T       = {0:12.5e} K'.format(T[im1]))
              print('epsilon = {0:12.5e} ergs/g/s'.format(epslon[im1]))
              print('P       = {0:12.5e} dynes/cm**2'.format(P[im1]))
              print('L_r/Ls  = {0:12.5e}'.format(L_r[im1]/Ls))
              break
#
#  Update stellar parameters for the next zone, including adding
#  dr to the old radius (note that dr <  0 since the integration is
#  inward).
#
          r[i]   = r[im1] + deltar
          P[i]   = f_i[0]
          M_r[i] = f_i[1]
          L_r[i] = f_i[2]
          T[i]   = f_i[3]
#
#  Calculate the density, opacity, and energy generation rate for
#  this zone.
#
          rho[i],kappa[i],epslon[i],tog_bf[i],ierr=EOS(X, Z, XCNO, mu, P[i], T[i], i, cst)

          if (ierr != 0):
              print(' Values from the previous zone are:')
              print('r/Rs    = {0:12.5e}'.format(r[im1]/Rs))
              print('rho     = {0:12.5e} g/cm**3'.format(rho[im1]))
              print('M_r/Ms  = {0:12.5e}'.format(M_r[im1]/Ms))
              print('kappa   = {0:12.5e} cm**2/g'.format(kappa[im1]))
              print('T       = {0:12.5e} K'.format(T[im1]))
              print('epsilon = {0:12.5e} ergs/g/s'.format(epslon[im1]))
              print('P       = {0:12.5e} dynes/cm**2'.format(P[im1]))
              print('L_r/Ls  = {0:12.5e}'.format(L_r[im1]/Ls))
              istop = i
              break

          if (debug == 1): print (i,r[i],M_r[i],L_r[i],T[i],P[i],rho[i],kappa[i],epslon[i],tog_bf[i])



#
#  Determine whether convection will be operating in the next zone by
#  calculating dlnP/dlnT and comparing it to gamma/(gamma-1)
#  (see Prialnik Eq. 6.28 or C&O Eq. 10.87).  Set the convection flag appropriately.
#
          dlPdlT[i] = np.log(P[i]/P[im1])/np.log(T[i]/T[im1])
          if (dlPdlT[i] < cst.gamrat):
              irc = 1
          else:
              irc = 0

#
#  Check to see whether the center has been reached.  If so, set Igoof and
#  estimate the central conditions rhocor, epscor, Pcore, and Tcore.
#  The central density is estimated to be the average density of the
#  remaining central ball, the central pressure is determined by
#  using Taylor expansion at center (Prialnik - Exercise. 5.1; CO Eq. H.4)
#   and the central value for the energy
#  generation rate is calculated to be the remaining interior
#  luminosity divided by the mass of the central ball.  Finally, the
#  central temperature is computed by applying the ideal gas law
#  (where radiation pressure is neglected).
#
          if ((r[i] <= np.abs(deltar)) and ((L_r[i] >= (0.1e0*Ls)) or (M_r[i] >= (0.01e0*Ms)))):
              #   Hit center before mass/luminosity depleted
              Igoof = 6
          elif (L_r[i] <= 0.0e0):
              #   Obtained negative central luminosity
              Igoof = 5
              # rho: Taylor expansion at center
              rhocor = M_r[i]/(4.0e0/3.0e0*np.pi*r[i]**3)
              if (M_r[i] != 0.0e0):
                  # energy generation rate
                  epscor = L_r[i]/M_r[i]
              else:
                  epscor = 0.0e0
              # P:  Taylor expansion at center
              Pcore = P[i] + 2.0e0/3.0e0*np.pi*cst.G*rhocor**2*r[i]**2
              # Assume ideal gas
              Tcore = Pcore*mu*cst.m_H/(rhocor*cst.k_B)
          elif (M_r[i] <= 0.0e0):
              Igoof  = 4  #  Model has a hole in center (negative density!)
              Rhocor = 0.0e0
              epscor = 0.0e0
              Pcore  = 0.0e0
              Tcore  = 0.0e0
          elif ((r[i] < (0.02e0*Rs)) and ((M_r[i] < (0.01e0*Ms)) and ((L_r[i] < 0.1e0*Ls)))):
              #  if we've reached <2% star's radius,
              #<1% mass enclosed and <10% luminosity then....
              # rho: Taylor expansion at center
              rhocor = M_r[i]/(4./3.*np.pi*r[i]**3)
              # set maximum reasonable core mass
              rhomax = 10.0e0*(rho[i]/rho[im1])*rho[i]
              epscor = L_r[i]/M_r[i]
              # P: Taylor expansion at center
              Pcore  = P[i] + 2.0e0/3.0e0*np.pi*cst.G*rhocor**2*r[i]**2
              # Assume ideal gas
              Tcore  = Pcore*mu*cst.m_H/(rhocor*cst.k_B)
            # In general, these should all produce values
              # that rise towards center (but not too high)
              if ((rhocor < rho[i]) or (rhocor > rhomax)):
                  # rho is off either large or small
                  Igoof = 1
              elif (epscor < epslon[i]):
                  # energy generation rate a bit off (low)
                  Igoof = 2
              elif (Tcore < T[i]):
                  # Temperature a bit off (low)
                  Igoof = 3
              else:
                  # number of allowed shells has been exceeded
                  Igoof = 0

          if (Igoof != -1):
              istop = i
              break
#
#  Is it time to change the step size?
#
          if ((idrflg == 0) and (M_r[i] < (0.99e0*Ms))):
               deltar = (-1.0)*Rs/100.0e0
               idrflg = 1

          if ((idrflg == 1) and (deltar >= (0.5*r[i]))):
               deltar = (-1.0)*Rs/5000.0e0
               idrflg = 2

          istop = i

#
#  Generate warning messages for the central conditions.
#
      rhocor = M_r[istop]/(4.0e0/3.0e0*np.pi*r[istop]**3)
      epscor = L_r[istop]/M_r[istop]
      Pcore  = P[istop] + 2.0e0/3.0e0*np.pi*cst.G*rhocor**2*r[istop]**2
      Tcore  = Pcore*mu*cst.m_H/(rhocor*cst.k_B)

      if  (Igoof != 0):
          if (Igoof == -1):
              print('Sorry to be the bearer of bad news, but...')
              print('       Your model has some problems')
              print('The number of allowed shells has been exceeded')

          if (Igoof == 1):
              print('It looks like you are getting close,')
              print('however, there are still a few minor errors')
              print('The core density seems a bit off,')
              print(' density should increase smoothly toward the center.')
              print(' The density of the last zone calculated was rho = ',rho[istop],' gm/cm**3')
              print (rhocor,rhomax)
          if (rhocor > 1e10):
              print('It looks like you will need a degenerate')
              print(' neutron gas and general relativity')
              print(' to solve this core.  Who do you think I am, Einstein?')

          if (Igoof == 2):
              print('It looks like you are getting close,')
              print('however, there are still a few minor errors')
              print('The core epsilon seems a bit off,')
              print(' epsilon should vary smoothly near the center.')
              print(' The value calculated for the last zone was eps =',epslon[istop],' ergs/g/s')

          if (Igoof == 3):
              print('It looks like you are getting close,')
              print('however, there are still a few minor errors')
              print(' Your extrapolated central temperature is too low')
              print(' a little more fine tuning ought to do it.')
              print(' The value calculated for the last zone was T = ',T[istop],' K')

          if (Igoof == 4):
              print('Sorry to be the bearer of bad news, but...')
              print('       Your model has some problems')
              print('You created a star with a hole in the center!')

          if (Igoof == 5):
              print('Sorry to be the bearer of bad news, but...')
              print('       Your model has some problems')
              print('This star has a negative central luminosity!')

          if (Igoof == 6):
              print('Sorry to be the bearer of bad news, but...')
              print('       Your model has some problems')
              print('You hit the center before the mass and/or ')
              print('luminosity were depleted!')
      else:
          print('CONGRATULATIONS, I THINK YOU FOUND IT!')
          print('However, be sure to look at your model carefully.')

#
#  Print the central conditions.  If necessary, set limits for the
#  central radius, mass, and luminosity if necessary, to avoid format
#  field overflows.
#

      Rcrat = r[istop]/Rs
      if (Rcrat < -9.999e0): Rcrat = -9.999e0
      Mcrat = M_r[istop]/Ms
      if (Mcrat < -9.999e0): Mcrat = -9.999e0
      Lcrat = L_r[istop]/Ls
      if (Lcrat < -9.999e0): Lcrat = -9.999e0

      f=open(f'starmodl_py{iname}.dat','w')

      f.write('A Homogeneous Main-Sequence Model\n')
      f.write(' The surface conditions are:        The central conditions are:\n')
      f.write(' Mtot = {0:13.6E} Msun          Mc/Mtot     = {1:12.5E}\n'.format(Msolar,Mcrat))
      f.write(' Rtot = {0:13.6E} Rsun          Rc/Rtot     = {1:12.5E}\n'.format(Rsolar,Rcrat))
      f.write(' Ltot = {0:13.6E} Lsun          Lc/Ltot     = {1:12.5E}\n'.format(Lsolar,Lcrat))
      f.write(' Teff = {0:13.6E} K             Density     = {1:12.5E}\n'.format(Te,rhocor))
      f.write(' X    = {0:13.6E}               Temperature = {1:12.5E}\n'.format(X,Tcore))
      f.write(' Y    = {0:13.6E}               Pressure    = {1:12.5E} dynes/cm**2\n'.format(Y,Pcore))
      f.write(' Z    = {0:13.6E}               epsilon     = {1:12.5E} ergs/s/g\n'.format(Z,epscor))
      f.write('                                    dlnP/dlnT   = {0:12.5E}\n'.format(dlPdlT[istop]))

      f.write('Notes:\n')
      f.write(' (1) Mass is listed as Qm = 1.0 - M_r/Mtot, where Mtot = {0:13.6}\n'.format(Msun))
      f.write(' (2) Convective zones are indicated by c, radiative zones by r\n')
      f.write(' (3) dlnP/dlnT may be limited to +99.9 or -99.9# if so it is\n')
      f.write(' labeled by *\n')



#
#  Print data from the center of the star outward, labeling convective
#   or radiative zones by c or r, respectively.  If abs(dlnP/dlnT)
#  exceeds 99.9, set a print warning flag (*) and set the output limit
#  to +99.9 or -99.9 as appropriate to avoid format field overflows.
#
      f.write('   r        Qm       L_r       T        P        rho      kap      eps     dlPdlT\n')

      for ic in range(0,istop+1):
          i = istop - ic
          Qm = 1.0e0 - M_r[i]/Ms    # Total mass fraction down to radius


          if (dlPdlT[i] < cst.gamrat):
              rcf = 'c'
          else:
              rcf = 'r'
          if (np.abs(dlPdlT[i]) > dlPlim):
              dlPdlT[i] = np.copysign(dlPlim,dlPdlT[i])
              clim = '*'
          else:
              clim = ' '
          s='{0:7.2E} {1:7.2E} {2:7.2E} {3:7.2E} {4:7.2E} {5:7.2E} {6:7.2E} {7:6.2E}{8:1s}{9:1s} {10:5.1f}\n'.format(r[i], Qm, L_r[i], T[i], P[i], rho[i], kappa[i],epslon[i], clim, rcf, dlPdlT[i])
          f.write(s)

#     Output to screen
      print
      print('***** The integration has been completed *****')
      print('      The model has been stored in starmodl_py.dat')
      print
      return Igoof,ierr,istop, f'starmodl_py{iname}.dat'

# %% [markdown]
# # Step 2 - Load the Initial Conditions dataset to extract data with the StatStar Model.

# %%
df=pd.read_csv('stars_data_gen.csv').values
models=[]
for i in range(0,len(df)):
  Msolar=df[i][2]
  Lsolar=df[i][3]
  Te=df[i][4]
  X=df[i][5]
  Z=df[i][6]
  Y = 1.e0 - X - Z
  if Y < 0:
    continue

  Igoof,ierr,istop,model=StatStar(Msolar,Lsolar,Te,X,Z,i)
  models.append([model,df[i][0],df[i][1]])
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
#  Something is a little wrong here.
#  You are asking me to deal with either a negative temperature
#  or a negative pressure.  I am sorry but that is not in my
#  contract! You will have to try again with different
#  initial conditions.
#  In case it helps, I detected the problem in zone  452
#  with the following conditions:
# T =  -28802328.249582417  K
# P =  1.012236815549276e+18  dynes/cm**2
#  Values from the previous zone are:
# r/Rs    =  1.80000e-02
# rho     =  8.78243e+01 g/cm**3
# M_r/Ms  =  3.90302e-02
# kappa   =  9.05215e-01 cm**2/g
# T       =  2.07095e+07 K
# epsilon =  7.02944e+02 ergs/g/s
# P       =  2.49171e+17 dynes/cm**2
# L_r/Ls  =  4.38569e-01
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# The number of allowed shells has been exceeded
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
#  Something is a little wrong here.
#  You are asking me to deal with either a negative temperature
#  or a negative pressure.  I am sorry but that is not in my
#  contract! You will have to try again with different
#  initial conditions.
#  In case it helps, I detected the problem in zone  452
#  with the following conditions:
# T =  -28802328.249582417  K
# P =  1.012236815549276e+18  dynes/cm**2
#  Values from the previous zone are:
# r/Rs    =  1.80000e-02
# rho     =  8.78243e+01 g/cm**3
# M_r/Ms  =  3.90302e-02
# kappa   =  9.05215e-01 cm**2/g
# T       =  2.07095e+07 K
# epsilon =  7.02944e+02 ergs/g/s
# P       =  2.49171e+17 dynes/cm**2
# L_r/Ls  =  4.38569e-01
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# The number of allowed shells has been exceeded
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
#  Something is a little wrong here.
#  You are asking me to deal with either a negative temperature
#  or a negative pressure.  I am sorry but that is not in my
#  contract! You will have to try again with different
#  initial conditions.
#  In case it helps, I detected the problem in zone  452
#  with the following conditions:
# T =  -28802328.249582417  K
# P =  1.012236815549276e+18  dynes/cm**2
#  Values from the previous zone are:
# r/Rs    =  1.80000e-02
# rho     =  8.78243e+01 g/cm**3
# M_r/Ms  =  3.90302e-02
# kappa   =  9.05215e-01 cm**2/g
# T       =  2.07095e+07 K
# epsilon =  7.02944e+02 ergs/g/s
# P       =  2.49171e+17 dynes/cm**2
# L_r/Ls  =  4.38569e-01
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# The number of allowed shells has been exceeded
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
#  Something is a little wrong here.
#  You are asking me to deal with either a negative temperature
#  or a negative pressure.  I am sorry but that is not in my
#  contract! You will have to try again with different
#  initial conditions.
#  In case it helps, I detected the problem in zone  452
#  with the following conditions:
# T =  -28802328.249582417  K
# P =  1.012236815549276e+18  dynes/cm**2
#  Values from the previous zone are:
# r/Rs    =  1.80000e-02
# rho     =  8.78243e+01 g/cm**3
# M_r/Ms  =  3.90302e-02
# kappa   =  9.05215e-01 cm**2/g
# T       =  2.07095e+07 K
# epsilon =  7.02944e+02 ergs/g/s
# P       =  2.49171e+17 dynes/cm**2
# L_r/Ls  =  4.38569e-01
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# The number of allowed shells has been exceeded
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
#  Something is a little wrong here.
#  You are asking me to deal with either a negative temperature
#  or a negative pressure.  I am sorry but that is not in my
#  contract! You will have to try again with different
#  initial conditions.
#  In case it helps, I detected the problem in zone  452
#  with the following conditions:
# T =  -28802328.249582417  K
# P =  1.012236815549276e+18  dynes/cm**2
#  Values from the previous zone are:
# r/Rs    =  1.80000e-02
# rho     =  8.78243e+01 g/cm**3
# M_r/Ms  =  3.90302e-02
# kappa   =  9.05215e-01 cm**2/g
# T       =  2.07095e+07 K
# epsilon =  7.02944e+02 ergs/g/s
# P       =  2.49171e+17 dynes/cm**2
# L_r/Ls  =  4.38569e-01
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# The number of allowed shells has been exceeded
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
# ...
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
#  Something is a little wrong here.
#  You are asking me to deal with either a negative temperature
#  or a negative pressure.  I am sorry but that is not in my
#  contract! You will have to try again with different
#  initial conditions.
#  In case it helps, I detected the problem in zone  452
#  with the following conditions:
# T =  -28802328.249582417  K
# P =  1.012236815549276e+18  dynes/cm**2
#  Values from the previous zone are:
# r/Rs    =  1.80000e-02
# rho     =  8.78243e+01 g/cm**3
# M_r/Ms  =  3.90302e-02
# kappa   =  9.05215e-01 cm**2/g
# T       =  2.07095e+07 K
# epsilon =  7.02944e+02 ergs/g/s
# P       =  2.49171e+17 dynes/cm**2
# L_r/Ls  =  4.38569e-01
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# The number of allowed shells has been exceeded
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
#  Something is a little wrong here.
#  You are asking me to deal with either a negative temperature
#  or a negative pressure.  I am sorry but that is not in my
#  contract! You will have to try again with different
#  initial conditions.
#  In case it helps, I detected the problem in zone  452
#  with the following conditions:
# T =  -28802328.249582417  K
# P =  1.012236815549276e+18  dynes/cm**2
#  Values from the previous zone are:
# r/Rs    =  1.80000e-02
# rho     =  8.78243e+01 g/cm**3
# M_r/Ms  =  3.90302e-02
# kappa   =  9.05215e-01 cm**2/g
# T       =  2.07095e+07 K
# epsilon =  7.02944e+02 ergs/g/s
# P       =  2.49171e+17 dynes/cm**2
# L_r/Ls  =  4.38569e-01
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# The number of allowed shells has been exceeded
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You created a star with a hole in the center!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# You hit the center before the mass and/or
# luminosity were depleted!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat
# Sorry to be the bearer of bad news, but...
#        Your model has some problems
# This star has a negative central luminosity!
# ***** The integration has been completed *****
#       The model has been stored in starmodl_py.dat

# %% [markdown]
# # Checking the .dat Files

# %%
path='/content'
files=os.listdir(path)
files
# Out:
# ['.config',
#  'starmodl_py980.dat',
#  'starmodl_2936.csv',
#  'starmodl_3164.csv',
#  'starmodl_735.csv',
#  'starmodl_2838.csv',
#  'starmodl_171.csv',
#  'starmodl_py495.dat',
#  'starmodl_1354.csv',
#  'starmodl_py1562.dat',
#  'starmodl_3805.csv',
#  'starmodl_py436.dat',
#  'starmodl_3677.csv',
#  'starmodl_py1099.dat',
#  'starmodl_104.csv',
#  'starmodl_2109.csv',
#  'starmodl_py1558.dat',
#  'starmodl_1601.csv',
#  'starmodl_2126.csv',
#  'starmodl_119.csv',
#  'starmodl_1233.csv',
#  'starmodl_2322.csv',
#  'starmodl_1618.csv',
#  'starmodl_py1242.dat',
#  'starmodl_868.csv',
#  'starmodl_py219.dat',
#  'starmodl_2902.csv',
#  'starmodl_1216.csv',
#  'starmodl_2137.csv',
#  'starmodl_py1387.dat',
#  'starmodl_3931.csv',
#  'starmodl_1170.csv',
#  'starmodl_2066.csv',
#  'starmodl_2218.csv',
#  'starmodl_py1977.dat',
#  'starmodl_132.csv',
#  'starmodl_py543.dat',
#  'starmodl_3041.csv',
#  'starmodl_py1157.dat',
#  'starmodl_274.csv',
#  'starmodl_3620.csv',
#  'starmodl_py714.dat',
#  'starmodl_2592.csv',
#  'starmodl_3880.csv',
#  'starmodl_640.csv',
#  'starmodl_py1304.dat',
#  'starmodl_368.csv',
#  'starmodl_2917.csv',
#  'starmodl_1453.csv',
#  'starmodl_147.csv',
#  'starmodl_py140.dat',
#  'starmodl_py183.dat',
#  'starmodl_737.csv',
#  'starmodl_3758.csv',
#  'starmodl_2829.csv',
#  'starmodl_1543.csv',
#  'starmodl_py528.dat',
#  'starmodl_67.csv',
#  'starmodl_py1226.dat',
#  'starmodl_py1181.dat',
#  'starmodl_328.csv',
#  'starmodl_1623.csv',
#  'starmodl_266.csv',
#  'starmodl_2187.csv',
#  'starmodl_py1018.dat',
#  'starmodl_3973.csv',
#  'starmodl_46.csv',
#  'starmodl_3610.csv',
#  'starmodl_py1697.dat',
#  'starmodl_573.csv',
#  'starmodl_py877.dat',
#  'starmodl_3497.csv',
#  'starmodl_py1750.dat',
#  'starmodl_840.csv',
#  'starmodl_1942.csv',
#  'starmodl_75.csv',
#  'starmodl_2563.csv',
#  'starmodl_2121.csv',
#  'starmodl_623.csv',
#  'starmodl_py928.dat',
#  'starmodl_py97.dat',
#  'starmodl_py503.dat',
#  'starmodl_1644.csv',
#  'starmodl_553.csv',
#  'starmodl_py1436.dat',
#  'starmodl_2463.csv',
#  'starmodl_1842.csv',
#  'starmodl_py1059.dat',
#  'starmodl_3628.csv',
#  'starmodl_py854.dat',
#  'starmodl_3654.csv',
#  'starmodl_569.csv',
#  'starmodl_2953.csv',
#  'starmodl_py953.dat',
#  'starmodl_py1119.dat',
#  'starmodl_763.csv',
#  'starmodl_1208.csv',
#  'starmodl_py786.dat',
#  'starmodl_3496.csv',
#  'starmodl_1282.csv',
#  'starmodl_1207.csv',
#  'starmodl_py1687.dat',
#  'starmodl_py1273.dat',
#  'starmodl_1167.csv',
#  'starmodl_py1768.dat',
#  'starmodl_py1807.dat',
#  'starmodl_py317.dat',
#  'starmodl_3122.csv',
#  'starmodl_3405.csv',
#  'starmodl_883.csv',
#  'starmodl_1683.csv',
#  'starmodl_py148.dat',
#  'starmodl_907.csv',
#  'starmodl_3302.csv',
#  'starmodl_py473.dat',
#  'starmodl_3604.csv',
#  'starmodl_2353.csv',
#  'starmodl_py799.dat',
#  'starmodl_1580.csv',
#  'starmodl_py1648.dat',
#  'starmodl_2988.csv',
#  'starmodl_2046.csv',
#  'starmodl_py146.dat',
#  'starmodl_py1476.dat',
#  'starmodl_2927.csv',
#  'starmodl_996.csv',
#  'starmodl_927.csv',
#  'starmodl_1737.csv',
#  'starmodl_py1392.dat',
#  'starmodl_py976.dat',
#  'starmodl_3219.csv',
#  'starmodl_1903.csv',
#  'starmodl_2659.csv',
#  'starmodl_py858.dat',
#  'starmodl_py1571.dat',
#  'starmodl_692.csv',
#  'starmodl_2540.csv',
#  'starmodl_2807.csv',
#  'starmodl_py1404.dat',
#  'starmodl_py414.dat',
#  'starmodl_py1725.dat',
#  'starmodl_py1617.dat',
#  'starmodl_2634.csv',
#  'starmodl_818.csv',
#  'starmodl_230.csv',
#  'starmodl_2492.csv',
#  'starmodl_802.csv',
#  'starmodl_3522.csv',
#  'starmodl_3047.csv',
#  'starmodl_386.csv',
#  'starmodl_3240.csv',
#  'starmodl_1799.csv',
#  'starmodl_2908.csv',
#  'starmodl_1119.csv',
#  'starmodl_py721.dat',
#  'starmodl_981.csv',
#  'starmodl_187.csv',
#  'starmodl_1319.csv',
#  'starmodl_1377.csv',
#  'starmodl_3323.csv',
#  'starmodl_py1210.dat',
#  'starmodl_53.csv',
#  'starmodl_3063.csv',
#  'starmodl_441.csv',
#  'starmodl_py54.dat',
#  'starmodl_py1622.dat',
#  'starmodl_py1096.dat',
#  'starmodl_py1766.dat',
#  'starmodl_py1602.dat',
#  'starmodl_3760.csv',
#  'starmodl_py1182.dat',
#  'starmodl_3726.csv',
#  'starmodl_2016.csv',
#  'starmodl_py1309.dat',
#  'starmodl_2559.csv',
#  'starmodl_3551.csv',
#  'starmodl_2474.csv',
#  'starmodl_3269.csv',
#  'starmodl_1255.csv',
#  'starmodl_py736.dat',
#  'starmodl_357.csv',
#  'starmodl_py1184.dat',
#  'starmodl_1871.csv',
#  'starmodl_1882.csv',
#  'starmodl_2809.csv',
#  'starmodl_py692.dat',
#  'starmodl_py178.dat',
#  'starmodl_py80.dat',
#  'starmodl_py94.dat',
#  'starmodl_py566.dat',
#  'starmodl_py1785.dat',
#  'starmodl_3309.csv',
#  'starmodl_2312.csv',
#  'starmodl_3600.csv',
#  'starmodl_672.csv',
#  'starmodl_3422.csv',
#  'starmodl_2139.csv',
#  'starmodl_py1225.dat',
#  'starmodl_2768.csv',
#  'starmodl_3303.csv',
#  'starmodl_py160.dat',
#  'starmodl_py685.dat',
#  'starmodl_889.csv',
#  'starmodl_3064.csv',
#  'starmodl_929.csv',
#  'starmodl_62.csv',
#  'starmodl_py1345.dat',
#  'starmodl_2504.csv',
#  'starmodl_3967.csv',
#  'starmodl_3617.csv',
#  'starmodl_py673.dat',
#  'starmodl_py962.dat',
#  'starmodl_1430.csv',
#  'starmodl_2668.csv',
#  'starmodl_py1549.dat',
#  'starmodl_3957.csv',
#  'starmodl_py1168.dat',
#  'starmodl_2693.csv',
#  'starmodl_1314.csv',
#  'starmodl_3306.csv',
#  'starmodl_1970.csv',
#  'starmodl_py1524.dat',
#  'starmodl_py867.dat',
#  'starmodl_1473.csv',
#  'starmodl_py884.dat',
#  'starmodl_py166.dat',
#  'starmodl_py717.dat',
#  'starmodl_3844.csv',
#  'starmodl_3866.csv',
#  'starmodl_py754.dat',
#  'starmodl_py572.dat',
#  'starmodl_py548.dat',
#  'starmodl_2598.csv',
#  'starmodl_3105.csv',
#  'starmodl_1211.csv',
#  'starmodl_py1844.dat',
#  'starmodl_2591.csv',
#  'starmodl_543.csv',
#  'starmodl_69.csv',
#  'starmodl_2899.csv',
#  'starmodl_185.csv',
#  'starmodl_py983.dat',
#  'starmodl_1742.csv',
#  'starmodl_py168.dat',
#  'starmodl_py1252.dat',
#  'starmodl_2356.csv',
#  'starmodl_1179.csv',
#  'starmodl_2317.csv',
#  'starmodl_739.csv',
#  'starmodl_3308.csv',
#  'starmodl_2465.csv',
#  'starmodl_1435.csv',
#  'starmodl_2377.csv',
#  'starmodl_3900.csv',
#  'starmodl_1967.csv',
#  'starmodl_py608.dat',
#  'starmodl_1574.csv',
#  'starmodl_1001.csv',
#  'starmodl_3096.csv',
#  'starmodl_py1722.dat',
#  'starmodl_py1169.dat',
#  'starmodl_py847.dat',
#  'starmodl_py1241.dat',
#  'starmodl_1783.csv',
#  'starmodl_py592.dat',
#  'starmodl_508.csv',
#  'starmodl_395.csv',
#  'starmodl_2075.csv',
#  'starmodl_py170.dat',
#  'starmodl_py1450.dat',
#  'starmodl_527.csv',
#  'starmodl_3516.csv',
#  'starmodl_3693.csv',
#  'starmodl_py1888.dat',
#  'starmodl_1638.csv',
#  'starmodl_2315.csv',
#  'starmodl_2232.csv',
#  'starmodl_1679.csv',
#  'starmodl_1461.csv',
#  'starmodl_2759.csv',
#  'starmodl_py918.dat',
#  'starmodl_2661.csv',
#  'starmodl_3179.csv',
#  'starmodl_2060.csv',
#  'starmodl_493.csv',
#  'starmodl_5.csv',
#  'starmodl_1394.csv',
#  'starmodl_281.csv',
#  'starmodl_3570.csv',
#  'starmodl_1875.csv',
#  'starmodl_729.csv',
#  'starmodl_955.csv',
#  'starmodl_3215.csv',
#  'starmodl_1056.csv',
#  'starmodl_564.csv',
#  'starmodl_1485.csv',
#  'starmodl_py1467.dat',
#  'starmodl_649.csv',
#  'starmodl_py421.dat',
#  'starmodl_267.csv',
#  'starmodl_py852.dat',
#  'starmodl_2457.csv',
#  'starmodl_111.csv',
#  'starmodl_3264.csv',
#  'starmodl_778.csv',
#  'starmodl_py1981.dat',
#  'starmodl_py264.dat',
#  'starmodl_1584.csv',
#  'starmodl_3916.csv',
#  'starmodl_1029.csv',
#  'starmodl_1182.csv',
#  'starmodl_954.csv',
#  'starmodl_345.csv',
#  'starmodl_745.csv',
#  'starmodl_py1593.dat',
#  'starmodl_1023.csv',
#  'starmodl_2043.csv',
#  'starmodl_657.csv',
#  'starmodl_2454.csv',
#  'starmodl_py755.dat',
#  'starmodl_py402.dat',
#  'starmodl_1968.csv',
#  'starmodl_3974.csv',
#  'starmodl_py1386.dat',
#  'starmodl_2298.csv',
#  'starmodl_1806.csv',
#  'starmodl_2865.csv',
#  'starmodl_2545.csv',
#  'starmodl_1310.csv',
#  'starmodl_1101.csv',
#  'starmodl_py639.dat',
#  'starmodl_438.csv',
#  'starmodl_2618.csv',
#  'starmodl_2068.csv',
#  'starmodl_3708.csv',
#  'starmodl_2196.csv',
#  'starmodl_py1441.dat',
#  'starmodl_2757.csv',
#  'starmodl_2129.csv',
#  'starmodl_py1747.dat',
#  'starmodl_257.csv',
#  'starmodl_1080.csv',
#  'starmodl_2489.csv',
#  'starmodl_py1689.dat',
#  'starmodl_1057.csv',
#  'starmodl_1726.csv',
#  'starmodl_py320.dat',
#  'starmodl_424.csv',
#  'starmodl_py938.dat',
#  'starmodl_2819.csv',
#  'starmodl_3738.csv',
#  'starmodl_206.csv',
#  'starmodl_1390.csv',
#  'starmodl_py1048.dat',
#  'starmodl_py1269.dat',
#  'starmodl_1535.csv',
#  'starmodl_1931.csv',
#  'starmodl_py652.dat',
#  'starmodl_py1683.dat',
#  'starmodl_3008.csv',
#  'starmodl_3774.csv',
#  'starmodl_py1001.dat',
#  'starmodl_2509.csv',
#  'starmodl_957.csv',
#  'starmodl_700.csv',
#  'starmodl_py75.dat',
#  'starmodl_1514.csv',
#  'starmodl_1393.csv',
#  'starmodl_py654.dat',
#  'starmodl_3150.csv',
#  'starmodl_3657.csv',
#  'starmodl_py1699.dat',
#  'starmodl_py319.dat',
#  'starmodl_3464.csv',
#  'starmodl_py830.dat',
#  'starmodl_py1530.dat',
#  'starmodl_1454.csv',
#  'starmodl_2296.csv',
#  'starmodl_3958.csv',
#  'starmodl_998.csv',
#  'starmodl_1984.csv',
#  'starmodl_3892.csv',
#  'starmodl_py907.dat',
#  'starmodl_2364.csv',
#  'starmodl_py1208.dat',
#  'starmodl_1087.csv',
#  'starmodl_py1639.dat',
#  'starmodl_py900.dat',
#  'starmodl_py1442.dat',
#  'starmodl_py952.dat',
#  'starmodl_1605.csv',
#  'starmodl_1126.csv',
#  'starmodl_py1597.dat',
#  'starmodl_2017.csv',
#  'starmodl_3576.csv',
#  'starmodl_py667.dat',
#  'starmodl_788.csv',
#  'starmodl_3017.csv',
#  'starmodl_167.csv',
#  'starmodl_1146.csv',
#  'starmodl_py1835.dat',
#  'starmodl_py1955.dat',
#  'starmodl_853.csv',
#  'starmodl_3013.csv',
#  'starmodl_1935.csv',
#  'starmodl_1320.csv',
#  'starmodl_59.csv',
#  'starmodl_1973.csv',
#  'starmodl_py1927.dat',
#  'starmodl_1360.csv',
#  'starmodl_1215.csv',
#  'starmodl_py262.dat',
#  'starmodl_py1889.dat',
#  'starmodl_2062.csv',
#  'starmodl_1870.csv',
#  'starmodl_1337.csv',
#  'starmodl_py364.dat',
#  'starmodl_py1976.dat',
#  'starmodl_2753.csv',
#  'starmodl_py509.dat',
#  'starmodl_121.csv',
#  'starmodl_py1572.dat',
#  'starmodl_py1691.dat',
#  'starmodl_py1379.dat',
#  'starmodl_2091.csv',
#  'starmodl_py1556.dat',
#  'starmodl_py1249.dat',
#  'starmodl_py312.dat',
#  'starmodl_3407.csv',
#  'starmodl_3511.csv',
#  'starmodl_py1355.dat',
#  'starmodl_py944.dat',
#  'starmodl_2684.csv',
#  'starmodl_2929.csv',
#  'starmodl_1762.csv',
#  'starmodl_py730.dat',
#  'starmodl_3327.csv',
#  'starmodl_2868.csv',
#  'starmodl_py382.dat',
#  'starmodl_py683.dat',
#  'starmodl_py1733.dat',
#  'starmodl_2786.csv',
#  'starmodl_826.csv',
#  'starmodl_1426.csv',
#  'starmodl_1788.csv',
#  'starmodl_2379.csv',
#  'starmodl_220.csv',
#  'starmodl_py1618.dat',
#  'starmodl_1818.csv',
#  'starmodl_311.csv',
#  'starmodl_1428.csv',
#  'starmodl_9.csv',
#  'starmodl_176.csv',
#  'starmodl_py551.dat',
#  'starmodl_py1032.dat',
#  'starmodl_1542.csv',
#  'starmodl_py1932.dat',
#  'starmodl_1501.csv',
#  'starmodl_1640.csv',
#  'starmodl_3838.csv',
#  'starmodl_803.csv',
#  'starmodl_1890.csv',
#  'starmodl_758.csv',
#  'starmodl_py480.dat',
#  'starmodl_3625.csv',
#  'starmodl_1976.csv',
#  'starmodl_py1197.dat',
#  'starmodl_2416.csv',
#  'starmodl_py48.dat',
#  'starmodl_3945.csv',
#  'starmodl_py1676.dat',
#  'starmodl_1432.csv',
#  'starmodl_py432.dat',
#  'starmodl_199.csv',
#  'starmodl_1069.csv',
#  'starmodl_py1120.dat',
#  'starmodl_1550.csv',
#  'starmodl_1374.csv',
#  'starmodl_3939.csv',
#  'starmodl_2249.csv',
#  'starmodl_2794.csv',
#  'starmodl_py109.dat',
#  'starmodl_3770.csv',
#  'starmodl_py851.dat',
#  'starmodl_3871.csv',
#  'starmodl_py100.dat',
#  'starmodl_80.csv',
#  'starmodl_197.csv',
#  'starmodl_1522.csv',
#  'starmodl_py1250.dat',
#  'starmodl_2088.csv',
#  'starmodl_2420.csv',
#  'starmodl_py979.dat',
#  'starmodl_py1076.dat',
#  'starmodl_1910.csv',
#  'starmodl_1058.csv',
#  'starmodl_py1397.dat',
#  'starmodl_3915.csv',
#  'starmodl_1195.csv',
#  'starmodl_3833.csv',
#  'starmodl_2157.csv',
#  'starmodl_2522.csv',
#  'starmodl_893.csv',
#  'starmodl_599.csv',
#  'starmodl_3846.csv',
#  'starmodl_1609.csv',
#  'starmodl_py1515.dat',
#  'starmodl_1611.csv',
#  'starmodl_1488.csv',
#  'starmodl_275.csv',
#  'starmodl_py1220.dat',
#  'starmodl_1177.csv',
#  'starmodl_2494.csv',
#  'starmodl_309.csv',
#  'starmodl_1397.csv',
#  'starmodl_py1415.dat',
#  'starmodl_2992.csv',
#  'starmodl_2032.csv',
#  'starmodl_3099.csv',
#  'starmodl_2229.csv',
#  'starmodl_2498.csv',
#  'starmodl_563.csv',
#  'starmodl_2990.csv',
#  'starmodl_2265.csv',
#  'starmodl_306.csv',
#  'starmodl_2940.csv',
#  'starmodl_py57.dat',
#  'starmodl_2791.csv',
#  'starmodl_3820.csv',
#  'starmodl_3319.csv',
#  'starmodl_1852.csv',
#  'starmodl_py985.dat',
#  'starmodl_py246.dat',
#  'starmodl_1769.csv',
#  'starmodl_2637.csv',
#  'starmodl_py138.dat',
#  'starmodl_3818.csv',
#  'starmodl_452.csv',
#  'starmodl_py1305.dat',
#  'starmodl_3523.csv',
#  'starmodl_1653.csv',
#  'starmodl_py293.dat',
#  'starmodl_py880.dat',
#  'starmodl_331.csv',
#  'starmodl_py93.dat',
#  'starmodl_py1851.dat',
#  'starmodl_1174.csv',
#  'starmodl_278.csv',
#  'starmodl_98.csv',
#  'starmodl_1857.csv',
#  'starmodl_93.csv',
#  'starmodl_py1620.dat',
#  'starmodl_py1924.dat',
#  'starmodl_py368.dat',
#  'starmodl_2351.csv',
#  'starmodl_py1744.dat',
#  'starmodl_py1492.dat',
#  'starmodl_py700.dat',
#  'starmodl_3207.csv',
#  'starmodl_py1894.dat',
#  'starmodl_2597.csv',
#  'starmodl_py651.dat',
#  'starmodl_py777.dat',
#  'starmodl_3257.csv',
#  'starmodl_py823.dat',
#  'starmodl_py455.dat',
#  'starmodl_3710.csv',
#  'starmodl_1464.csv',
#  'starmodl_633.csv',
#  'starmodl_py1418.dat',
#  'starmodl_3259.csv',
#  'starmodl_462.csv',
#  'starmodl_py269.dat',
#  'starmodl_1500.csv',
#  'starmodl_3993.csv',
#  'starmodl_py583.dat',
#  'starmodl_py1519.dat',
#  'starmodl_782.csv',
#  'starmodl_2257.csv',
#  'starmodl_1873.csv',
#  'starmodl_py447.dat',
#  'starmodl_3589.csv',
#  'starmodl_py29.dat',
#  'starmodl_2099.csv',
#  'starmodl_1221.csv',
#  'starmodl_1096.csv',
#  'starmodl_1256.csv',
#  'starmodl_1241.csv',
#  'starmodl_py1755.dat',
#  'starmodl_760.csv',
#  'starmodl_py679.dat',
#  'starmodl_1805.csv',
#  'starmodl_py1829.dat',
#  'starmodl_py1011.dat',
#  'starmodl_165.csv',
#  'starmodl_py496.dat',
#  'starmodl_3635.csv',
#  'starmodl_py1657.dat',
#  'starmodl_3116.csv',
#  'starmodl_3324.csv',
#  'starmodl_3250.csv',
#  'starmodl_py955.dat',
#  'starmodl_py859.dat',
#  'starmodl_470.csv',
#  'starmodl_36.csv',
#  'starmodl_338.csv',
#  'starmodl_py577.dat',
#  'starmodl_py98.dat',
#  'starmodl_3479.csv',
#  'starmodl_2409.csv',
#  'starmodl_979.csv',
#  'starmodl_3284.csv',
#  'starmodl_2000.csv',
#  'starmodl_2455.csv',
#  'starmodl_3927.csv',
#  'starmodl_py599.dat',
#  'starmodl_1422.csv',
#  'starmodl_py862.dat',
#  'starmodl_py811.dat',
#  'starmodl_py819.dat',
#  'starmodl_1224.csv',
#  'starmodl_1050.csv',
#  'starmodl_1558.csv',
#  'starmodl_py829.dat',
#  'starmodl_2328.csv',
#  'starmodl_1244.csv',
#  'starmodl_1824.csv',
#  'starmodl_py891.dat',
#  'starmodl_py1943.dat',
#  'starmodl_3791.csv',
#  'starmodl_1362.csv',
#  'starmodl_py384.dat',
#  'starmodl_579.csv',
#  'starmodl_2552.csv',
#  'starmodl_py259.dat',
#  'starmodl_1672.csv',
#  'starmodl_836.csv',
#  'starmodl_1786.csv',
#  'starmodl_29.csv',
#  'starmodl_3699.csv',
#  'starmodl_1974.csv',
#  'starmodl_py1907.dat',
#  'starmodl_py1635.dat',
#  'starmodl_py1859.dat',
#  'starmodl_2173.csv',
#  'starmodl_3772.csv',
#  'starmodl_py327.dat',
#  'starmodl_3380.csv',
#  'starmodl_py587.dat',
#  'starmodl_3028.csv',
#  'starmodl_2069.csv',
#  'starmodl_1668.csv',
#  'starmodl_py359.dat',
#  'starmodl_py121.dat',
#  'starmodl_py403.dat',
#  'starmodl_1518.csv',
#  'starmodl_1384.csv',
#  'starmodl_2772.csv',
#  'starmodl_py1189.dat',
#  'starmodl_py1385.dat',
#  'starmodl_1741.csv',
#  'starmodl_596.csv',
#  'starmodl_py1380.dat',
#  'starmodl_3595.csv',
#  'starmodl_py274.dat',
#  'starmodl_py617.dat',
#  'starmodl_2372.csv',
#  'starmodl_py465.dat',
#  'starmodl_3194.csv',
#  'starmodl_3534.csv',
#  'starmodl_828.csv',
#  'starmodl_3443.csv',
#  'starmodl_3598.csv',
#  'starmodl_489.csv',
#  'starmodl_py940.dat',
#  'starmodl_1040.csv',
#  'starmodl_py249.dat',
#  'starmodl_3585.csv',
#  'starmodl_3504.csv',
#  'starmodl_3121.csv',
#  'starmodl_2621.csv',
#  'starmodl_3941.csv',
#  'starmodl_515.csv',
#  'starmodl_2893.csv',
#  'starmodl_py806.dat',
#  'starmodl_py430.dat',
#  'starmodl_py112.dat',
#  'starmodl_py1856.dat',
#  'starmodl_1264.csv',
#  'starmodl_py342.dat',
#  'starmodl_1666.csv',
#  'starmodl_3614.csv',
#  'starmodl_2894.csv',
#  'starmodl_py1969.dat',
#  'starmodl_591.csv',
#  'starmodl_1348.csv',
#  'starmodl_939.csv',
#  'starmodl_3660.csv',
#  'starmodl_py1535.dat',
#  'starmodl_py1811.dat',
#  'starmodl_1335.csv',
#  'starmodl_150.csv',
#  'starmodl_3541.csv',
#  'starmodl_1478.csv',
#  'starmodl_3502.csv',
#  'starmodl_1355.csv',
#  'starmodl_2909.csv',
#  'starmodl_2565.csv',
#  'starmodl_3295.csv',
#  'starmodl_2746.csv',
#  'starmodl_602.csv',
#  'starmodl_2424.csv',
#  'starmodl_1093.csv',
#  'starmodl_100.csv',
#  'starmodl_2948.csv',
#  'starmodl_629.csv',
#  'starmodl_3247.csv',
#  'starmodl_40.csv',
#  'starmodl_1603.csv',
#  'starmodl_1663.csv',
#  'starmodl_3089.csv',
#  'starmodl_py164.dat',
#  'starmodl_4002.csv',
#  'starmodl_138.csv',
#  'starmodl_3304.csv',
#  'starmodl_py565.dat',
#  'starmodl_3944.csv',
#  'starmodl_2248.csv',
#  'starmodl_3340.csv',
#  'starmodl_2367.csv',
#  'starmodl_313.csv',
#  'starmodl_3230.csv',
#  'starmodl_1891.csv',
#  'starmodl_3149.csv',
#  'starmodl_py1719.dat',
#  'starmodl_3744.csv',
#  'starmodl_py1696.dat',
#  'starmodl_1632.csv',
#  'starmodl_py1496.dat',
#  'starmodl_625.csv',
#  'starmodl_3697.csv',
#  'starmodl_2511.csv',
#  'starmodl_348.csv',
#  'starmodl_2450.csv',
#  'starmodl_531.csv',
#  'starmodl_2467.csv',
#  'starmodl_3655.csv',
#  'starmodl_1561.csv',
#  'starmodl_py674.dat',
#  'starmodl_2005.csv',
#  'starmodl_1859.csv',
#  'starmodl_py1738.dat',
#  'starmodl_189.csv',
#  'starmodl_1446.csv',
#  'starmodl_py603.dat',
#  'starmodl_3759.csv',
#  'starmodl_3363.csv',
#  'starmodl_py485.dat',
#  'starmodl_2337.csv',
#  'starmodl_py712.dat',
#  'starmodl_py606.dat',
#  'starmodl_2380.csv',
#  'starmodl_127.csv',
#  'starmodl_173.csv',
#  'starmodl_py1810.dat',
#  'starmodl_py800.dat',
#  'starmodl_py904.dat',
#  'starmodl_py39.dat',
#  'starmodl_py1376.dat',
#  'starmodl_2181.csv',
#  'starmodl_1982.csv',
#  'starmodl_py218.dat',
#  'starmodl_2477.csv',
#  'starmodl_753.csv',
#  'starmodl_py1434.dat',
#  'starmodl_3801.csv',
#  'starmodl_3577.csv',
#  'starmodl_2484.csv',
#  'starmodl_py1637.dat',
#  'starmodl_py871.dat',
#  'starmodl_3748.csv',
#  'starmodl_py392.dat',
#  'starmodl_172.csv',
#  'starmodl_35.csv',
#  'starmodl_57.csv',
#  'starmodl_3175.csv',
#  'starmodl_342.csv',
#  'starmodl_py1440.dat',
#  'starmodl_361.csv',
#  'starmodl_py356.dat',
#  'starmodl_3139.csv',
#  'starmodl_2685.csv',
#  'starmodl_1837.csv',
#  'starmodl_2689.csv',
#  'starmodl_2667.csv',
#  'starmodl_2414.csv',
#  'starmodl_1003.csv',
#  'starmodl_2677.csv',
#  'starmodl_475.csv',
#  'starmodl_1440.csv',
#  'starmodl_py857.dat',
#  'starmodl_517.csv',
#  'starmodl_1557.csv',
#  'starmodl_3273.csv',
#  'starmodl_1260.csv',
#  'starmodl_3962.csv',
#  'starmodl_2294.csv',
#  'starmodl_py525.dat',
#  'starmodl_595.csv',
#  'starmodl_730.csv',
#  'starmodl_py378.dat',
#  'starmodl_py738.dat',
#  'starmodl_py1956.dat',
#  'starmodl_py1421.dat',
#  'starmodl_py1330.dat',
#  'starmodl_634.csv',
#  'starmodl_3663.csv',
#  'starmodl_py1814.dat',
#  'starmodl_3457.csv',
#  'starmodl_963.csv',
#  'starmodl_py1529.dat',
#  'starmodl_3468.csv',
#  'starmodl_py1607.dat',
#  'starmodl_py1542.dat',
#  'starmodl_777.csv',
#  'starmodl_651.csv',
#  'starmodl_2901.csv',
#  'starmodl_3256.csv',
#  'starmodl_py215.dat',
#  'starmodl_906.csv',
#  'starmodl_1034.csv',
#  'starmodl_py1042.dat',
#  'starmodl_3151.csv',
#  'starmodl_908.csv',
#  'starmodl_2395.csv',
#  'starmodl_py1522.dat',
#  'starmodl_534.csv',
#  'starmodl_1247.csv',
#  'starmodl_1505.csv',
#  'starmodl_py396.dat',
#  'starmodl_py468.dat',
#  'starmodl_2586.csv',
#  'starmodl_1467.csv',
#  'starmodl_3433.csv',
#  'starmodl_3360.csv',
#  'starmodl_678.csv',
#  'starmodl_py571.dat',
#  'starmodl_801.csv',
#  'starmodl_847.csv',
#  'starmodl_3400.csv',
#  'starmodl_3735.csv',
#  'starmodl_py267.dat',
#  'starmodl_874.csv',
#  'starmodl_3588.csv',
#  'starmodl_1728.csv',
#  'starmodl_3794.csv',
#  'starmodl_2130.csv',
#  'starmodl_129.csv',
#  'starmodl_2383.csv',
#  'starmodl_1349.csv',
#  'starmodl_113.csv',
#  'starmodl_1458.csv',
#  'starmodl_py1163.dat',
#  'starmodl_2928.csv',
#  'starmodl_2720.csv',
#  'starmodl_py1521.dat',
#  'starmodl_py199.dat',
#  'starmodl_3211.csv',
#  'starmodl_py814.dat',
#  'starmodl_3131.csv',
#  'starmodl_py1808.dat',
#  'starmodl_2897.csv',
#  'starmodl_3762.csv',
#  'starmodl_py173.dat',
#  'starmodl_482.csv',
#  'starmodl_270.csv',
#  'starmodl_1560.csv',
#  'starmodl_414.csv',
#  'starmodl_2287.csv',
#  'starmodl_458.csv',
#  'starmodl_3764.csv',
#  'starmodl_1448.csv',
#  'starmodl_py870.dat',
#  'starmodl_py797.dat',
#  'starmodl_502.csv',
#  'starmodl_py17.dat',
#  'starmodl_3731.csv',
#  'starmodl_401.csv',
#  'starmodl_387.csv',
#  'starmodl_2963.csv',
#  'starmodl_411.csv',
#  'starmodl_2821.csv',
#  'starmodl_2571.csv',
#  'starmodl_py351.dat',
#  'starmodl_py1158.dat',
#  'starmodl_2863.csv',
#  'starmodl_589.csv',
#  'starmodl_py315.dat',
#  'starmodl_372.csv',
#  'starmodl_430.csv',
#  'starmodl_1375.csv',
#  'starmodl_2408.csv',
#  'starmodl_902.csv',
#  'starmodl_1754.csv',
#  'starmodl_py1729.dat',
#  'starmodl_504.csv',
#  'starmodl_py1468.dat',
#  'starmodl_3743.csv',
#  'starmodl_py794.dat',
#  'starmodl_3827.csv',
#  'starmodl_3665.csv',
#  'starmodl_1532.csv',
#  'starmodl_2704.csv',
#  'starmodl_673.csv',
#  'starmodl_3100.csv',
#  'starmodl_1175.csv',
#  'starmodl_3210.csv',
#  'starmodl_py1362.dat',
#  'starmodl_py1935.dat',
#  'starmodl_3956.csv',
#  'starmodl_py1739.dat',
#  'starmodl_2777.csv',
#  'starmodl_py213.dat',
#  'starmodl_1441.csv',
#  'starmodl_290.csv',
#  'starmodl_py1457.dat',
#  'starmodl_py1564.dat',
#  'starmodl_1419.csv',
#  'starmodl_py1778.dat',
#  'starmodl_3009.csv',
#  'starmodl_py632.dat',
#  'starmodl_155.csv',
#  'starmodl_671.csv',
#  'starmodl_3547.csv',
#  'starmodl_1062.csv',
#  'starmodl_3689.csv',
#  'starmodl_551.csv',
#  'starmodl_3605.csv',
#  'starmodl_py769.dat',
#  'starmodl_py78.dat',
#  'starmodl_1169.csv',
#  'starmodl_3792.csv',
#  'starmodl_2568.csv',
#  'starmodl_1109.csv',
#  'starmodl_580.csv',
#  'starmodl_1444.csv',
#  'starmodl_2776.csv',
#  'starmodl_py511.dat',
#  'starmodl_py240.dat',
#  'starmodl_972.csv',
#  'starmodl_py1867.dat',
#  'starmodl_py666.dat',
#  'starmodl_1685.csv',
#  'starmodl_2810.csv',
#  'starmodl_py377.dat',
#  'starmodl_py1356.dat',
#  'starmodl_py1781.dat',
#  'starmodl_1248.csv',
#  'starmodl_255.csv',
#  'starmodl_3531.csv',
#  'starmodl_2701.csv',
#  'starmodl_45.csv',
#  'starmodl_3289.csv',
#  'starmodl_3216.csv',
#  'starmodl_1074.csv',
#  'starmodl_2347.csv',
#  'starmodl_3565.csv',
#  'starmodl_2519.csv',
#  'starmodl_py1998.dat',
#  'starmodl_3983.csv',
#  'starmodl_1526.csv',
#  'starmodl_py212.dat',
#  'starmodl_py1668.dat',
#  'starmodl_728.csv',
#  'starmodl_1688.csv',
#  'starmodl_py1664.dat',
#  'starmodl_3313.csv',
#  'starmodl_py1020.dat',
#  'starmodl_695.csv',
#  'starmodl_py1801.dat',
#  'starmodl_2690.csv',
#  'starmodl_748.csv',
#  'starmodl_958.csv',
#  'starmodl_3659.csv',
#  'starmodl_1083.csv',
#  'starmodl_520.csv',
#  'starmodl_2952.csv',
#  'starmodl_py729.dat',
#  'starmodl_1031.csv',
#  'starmodl_518.csv',
# Iteration 6003 of 6005.
# Iteration 6004 of 6005.
# Iteration 6005 of 6005.

# %% [markdown]
# # Step 4 - A Loop to Generate dataframes from .csv files and separating the important variables for the model.

# %%
files=os.listdir(path)
for file in files:
  if file[-3:]=='csv':
    try:
      df=pd.read_csv(f'/content/{file}',skiprows=15)
      radius=df['r']
      temperature=df['T']
      density=df['rho']
      mass=df['Qm']
    except:
      pass

# %% [markdown]
# # Step 5 - Using the first Dataset as an example

# %%
df=pd.read_csv('/content/starmodl_1.csv',skiprows=15)
radius=df['r'].values
temperature=df['T'].values
density=df['rho'].values
mass=df['Qm'].values
star_age=df.reset_index()['index'].values

# %% [markdown]
# # Step 6 - Visualizing Data

# %%
variables=[radius,temperature,density,mass]
labels=['Radius of Star/Radius of Sun','Temperature of Star', 'Density of Star', 'Mass of Star/Mass of Sun']
sns.set(style="whitegrid")
i=0
for value in variables:
  plt.plot(star_age,value)
  # Add x and y-axis labels
  plt.xlabel("Star_Age")
  plt.ylabel(labels[i])
  plt.show()
  i+=1

# %% [markdown]
# # Step 7 - Normalizing Data

# %%
radius=radius-np.mean(radius) #exp
temperature=temperature-np.mean(temperature) #exp
density=density-np.mean(density) #exp
mass=mass-np.mean(mass) #exp

# %% [markdown]
# # Step 8 - Plotting Radius Function by Exponential fitting

# %%
plt.plot(radius)
plt.plot(np.exp(radius))

# %% [markdown]
# # Step 9 - Visualizing the Difference between the square of delta maximum values and the square of delta minimum values of the radius function.

# %%
diff=((max(np.exp(radius))-max(radius))**2-(min(np.exp(radius))-min(radius))**2)
print(diff)
# Out:
# 1.1818700387037104

# %%
plt.plot(radius, label="Real Value for Radius/Sun Radius")
plt.plot(np.exp(radius)-diff, label="Predicted by exponential model")
sns.set(style="whitegrid")
plt.xlabel("Steps")
plt.legend()
plt.title("Comparison of Real and Predicted Values for Radius/Sun Radius")
plt.show()

# %% [markdown]
# # Step 10 - Creating and visualizing the Autocorrelation Function

# %%
def autocor(data):
    return acf(data, nlags=len(data) - 1)

# %%
fig=plt.figure(figsize=(20,10))
x1 = autocor(radius)
shifted_output = np.concatenate((np.zeros(3), x1[:-3]))
# Subtract the corresponding samples
auto_correlation = x1 - shifted_output
plt.plot(auto_correlation)
plt.title("Autocorrelation of values (Should be a Delta Function)")
# Out:
# Text(0.5, 1.0, 'Autocorrelation of values (Should be a Delta Function)')

# %%
fig, ax = plt.subplots(figsize=(8,4))
plot_acf(radius, ax=ax, lags=20)
ax.set_xlim(0.20)
ax.set_ylim(-0.2,1.0)
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Sample Autocorrelation Function')
plt.grid(True)
plt.show()

# %%
fig=plt.figure(figsize=(20,10))
x1 = autocor(radius-(np.exp(radius)-diff))
shifted_output = np.concatenate((np.zeros(3), x1[:-3]))
auto_correlation = x1 - shifted_output
plt.title("Autocorrelation of Residual values (Should be a Delta Function)")
plt.plot(auto_correlation)

# %%
fig, ax = plt.subplots(figsize=(8,4))
plot_acf(radius-(np.exp(radius)-diff), ax=ax, lags=20)
ax.set_xlim(0.20)
ax.set_ylim(-0.2,1.0)
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Sample Autocorrelation Function')
plt.grid(True)
plt.show()

# %% [markdown]
# # Step 11 - Visualizing Real and Model Functions

# %%
x1 = autocor(radius)
x2 = autocor(radius-(np.exp(radius)-diff))

plt.plot(x1[:200])
plt.plot(x2[:200])

# %% [markdown]
# # Step 12 - Developing a linear regression Algorithm for testing

# %%
X=radius
y_list=[]
x_list=[]
for i in range(3, len(X)):
  try:
    y_list.append([X[i-1],X[i-2],X[i-3]])
    x_list.append([X[i]])
  except Exception as e:
    print(e)
    pass
x=np.array(y_list)
y=np.array(x_list)

# %% [markdown]
# # Step 13 - Developing a linear Neural Network with 1 layer

# %%
def build_nn(input_shape):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(1, input_shape=input_shape, activation='linear'))

    return model

input_shape = (x.shape[1],)

model = build_nn(input_shape)
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# #Step 14 - Training the model with 10000 steps

# %%
history=model.fit(x, y, epochs=4000, batch_size=32)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 15/15 [==============================] - 0s 2ms/step - loss: 8.9503e-08
# Epoch 1502/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 6.0801e-08
# Epoch 1503/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 6.5397e-08
# Epoch 1504/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.8059e-08
# Epoch 1505/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 6.0625e-08
# Epoch 1506/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 3.3480e-08
# Epoch 1507/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.8515e-08
# Epoch 1508/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.0473e-07
# Epoch 1509/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.7451e-08
# Epoch 1510/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.9267e-08
# Epoch 1511/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 4.7040e-08
# Epoch 1512/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.2511e-08
# Epoch 1513/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.9510e-07
# Epoch 1514/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 2.8818e-07
# Epoch 1515/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.7956e-07
# Epoch 1516/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 5.0604e-08
# Epoch 1517/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.5990e-08
# Epoch 1518/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.6214e-08
# Epoch 1519/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 5.3147e-08
# Epoch 1520/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 2.4845e-08
# Epoch 1521/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.7738e-08
# Epoch 1522/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 4.5383e-08
# Epoch 1523/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.1951e-08
# Epoch 1524/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 4.7546e-08
# Epoch 1525/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 3.2381e-08
# Epoch 1526/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 3.8072e-08
# Epoch 1527/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 6.6551e-08
# Epoch 1528/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.2034e-08
# Epoch 1529/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 9.1142e-08
# Epoch 1530/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.6110e-08
# Epoch 1531/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.1065e-08
# Epoch 1532/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 6.6301e-08
# Epoch 1533/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.4066e-08
# Epoch 1534/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.0795e-08
# Epoch 1535/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.0898e-08
# Epoch 1536/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.6709e-08
# Epoch 1537/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.4051e-08
# Epoch 1538/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.1251e-08
# Epoch 1539/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 1.0485e-07
# Epoch 1540/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.7011e-08
# Epoch 1541/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.9719e-08
# Epoch 1542/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.6927e-08
# Epoch 1543/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.7969e-08
# Epoch 1544/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 8.3773e-08
# Epoch 1545/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.8920e-08
# Epoch 1546/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 7.9489e-08
# Epoch 1547/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 9.8540e-08
# Epoch 1548/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.7968e-08
# Epoch 1549/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 9.1335e-08
# Epoch 1550/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.2376e-08
# Epoch 1551/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.0567e-07
# Epoch 1552/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 8.8550e-08
# Epoch 1553/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 1.7215e-07
# Epoch 1554/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 7.5123e-08
# Epoch 1555/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 6.2763e-08
# Epoch 1556/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.0965e-08
# Epoch 1557/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 5.4294e-08
# Epoch 1558/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 6.4176e-08
# Epoch 1559/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 6.5142e-08
# Epoch 1560/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 1.1940e-07
# Epoch 1561/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 9.7812e-08
# Epoch 1562/4000
# 15/15 [==============================] - 0s 5ms/step - loss: 1.0923e-07
# Epoch 1563/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.6531e-08
# Epoch 1564/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 4.4222e-08
# Epoch 1565/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.4540e-08
# Epoch 1566/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 1.0993e-07
# Epoch 1567/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.0499e-07
# Epoch 1568/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 7.7279e-08
# Epoch 1569/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.4902e-08
# Epoch 1570/4000
# 15/15 [==============================] - 0s 3ms/step - loss: 4
4000
# 15/15 [==============================] - 0s 2ms/step - loss: 9.6247e-08
# Epoch 3970/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 7.9848e-08
# Epoch 3971/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.7105e-08
# Epoch 3972/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 2.9630e-08
# Epoch 3973/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 6.2378e-08
# Epoch 3974/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 7.1261e-08
# Epoch 3975/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2896e-07
# Epoch 3976/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 2.0165e-07
# Epoch 3977/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 1.0277e-07
# Epoch 3978/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 8.8937e-08
# Epoch 3979/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.8029e-08
# Epoch 3980/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.0963e-08
# Epoch 3981/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.0582e-08
# Epoch 3982/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.1801e-08
# Epoch 3983/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.3241e-08
# Epoch 3984/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.6520e-08
# Epoch 3985/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 6.1761e-08
# Epoch 3986/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 6.2934e-08
# Epoch 3987/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 1.0901e-07
# Epoch 3988/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 6.3457e-08
# Epoch 3989/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.6106e-08
# Epoch 3990/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.8269e-08
# Epoch 3991/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.3265e-08
# Epoch 3992/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.6682e-08
# Epoch 3993/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.5011e-08
# Epoch 3994/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 1.0737e-07
# Epoch 3995/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.6558e-08
# Epoch 3996/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.9069e-08
# Epoch 3997/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 5.2049e-08
# Epoch 3998/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 4.5025e-08
# Epoch 3999/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.5142e-08
# Epoch 4000/4000
# 15/15 [==============================] - 0s 2ms/step - loss: 3.6363e-08

# %% [markdown]
# # Step 15 - Visualizing the loss function

# %%
fig,ax=plt.subplots(figsize=(14,12))
plt.plot(history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss Function')
plt.title('Loss Function per Epoch')
plt.grid(True)
plt.show()

# %% [markdown]
# # Step 16 - Applying Fourier Transform on Loss Function for valuating results

# %%
fig,ax=plt.subplots(figsize=(14,12))
plt.plot(np.fft.fft(history.history['loss'])[:4000])
plt.xlabel('Epochs')
plt.ylabel('Loss Function')
plt.title('Loss Function per Epoch')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# # Step 17 - Analyzing Autocorrelation

# %%
fig, ax = plt.subplots(figsize=(8,4))
plot_acf(np.fft.fft(history.history['loss'])[:4000], ax=ax, lags=20)
ax.set_ylim(-0.2,1.5)
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Sample Autocorrelation Function')
plt.grid(True)
plt.show()

# %% [markdown]
# # Step 18 - Predicting Data and Visualizating Data

# %%
yHat=model.predict(x)
# Out:
# 15/15 [==============================] - 0s 2ms/step

# %%
fig=plt.figure(figsize=(20,10))
plt.plot(y, label='Real output')
plt.scatter(range(len(yHat)), yHat, label='Predicted output', s=7.5)
sns.set(style="whitegrid")
plt.xlabel("Steps")
plt.legend()
plt.title("Comparison of Real and Predicted Values for Radius/Sun Radius using a 1 Layer Neural Network")
plt.show()

# %% [markdown]
# # Step 19 - Autocorrelation

# %%
fig=plt.figure(figsize=(20,10))
x1 = autocor(y)
shifted_output = np.concatenate((np.zeros(3), x1[:-3]))
auto_correlation = x1 - shifted_output
plt.plot(auto_correlation)

# %%
fig, ax = plt.subplots(figsize=(8,4))
plot_acf(auto_correlation, ax=ax, lags=20)
ax.set_xlim(0.20)
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Sample Autocorrelation Function')
plt.grid(True)
plt.show()

# %%
fig=plt.figure(figsize=(20,10))
x1 = autocor(y-yHat)
shifted_output = np.concatenate((np.zeros(3), x1[:-3]))
auto_correlation = x1 - shifted_output
plt.plot(auto_correlation)

# %%
fig, ax = plt.subplots(figsize=(8,4))
plot_acf(auto_correlation, ax=ax, lags=20)
ax.set_xlim(0.20)
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Sample Autocorrelation Function for Residual Data')
plt.grid(True)
plt.show()

# %% [markdown]
# # Step 20 - Saving Model

# %%
model.save('radius_star.h5')
